# %%
import pandas as pd

df = pd.DataFrame({
   'X': ['A', 'B', 'O'],
   'Y': [15, 32, 12],
   'Z': [10, 29, 0],
   'T': [12, 28, 19]},
   index = [1, 2, 3]
)

# %%
df.head(3)
# Out:
#     X   Y   Z   T
# 1  13  15  10  12
# 2  30  32  29  28
# 3   A   B   O  AB

# %%
import pandas as pd

df = pd.DataFrame(
   data=[[1, 2, 3],
         [4, None, 5],
         [7, 8, 9]],
   columns=['X', 'Y', 'Z'],
   index=[1, 2, 3]
)
df.head(3)
# Out:
#    X    Y  Z
# 1  1  2.0  3
# 2  4  NaN  5
# 3  7  8.0  9

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head(5)
df.iloc[-5:].to_csv('data.csv')

# %%
! cat data.csv
# Out:
# ,longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value
# 16995,-124.26,40.58,52.0,2217.0,394.0,907.0,369.0,2.3571,111400.0
# 16996,-124.27,40.69,36.0,2349.0,528.0,1194.0,465.0,2.5179,79000.0
# 16997,-124.3,41.84,17.0,2677.0,531.0,1244.0,456.0,3.0313,103600.0
# 16998,-124.3,41.8,19.0,2672.0,552.0,1298.0,478.0,1.9797,85800.0
# 16999,-124.35,40.54,52.0,1820.0,300.0,806.0,270.0,3.0147,94600.0

# %%
print(df['median_house_value'])
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %%
print(df.loc[0,
'median_house_value'])
# Out:
# 66900.0

# %%
print(df.iloc[-1])
# Out:
# longitude              -124.3500
# latitude                 40.5400
# housing_median_age       52.0000
# total_rooms            1820.0000
# total_bedrooms          300.0000
# population              806.0000
# households              270.0000
# median_income             3.0147
# median_house_value    94600.0000
# Name: 16999, dtype: float64

# %%
import numpy as np

df.pivot_table(index='housing_median_age',
        columns=['total_rooms', 'total_bedrooms'],
        values='median_house_value',
        aggfunc=np.mean)
# Out:
# total_rooms          2.0       8.0       11.0     ...   32054.0   32627.0   37937.0
# total_bedrooms        2.0       1.0       11.0    ...    5290.0    6445.0    5471.0
# housing_median_age                                ...
# 1.0                      NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2.0                      NaN       NaN       NaN  ...       NaN       NaN       NaN
# 3.0                      NaN       NaN       NaN  ...       NaN       NaN       NaN
# 4.0                 137500.0       NaN       NaN  ...       NaN       NaN  366300.0
# 5.0                      NaN       NaN       NaN  ...       NaN       NaN       NaN
# 6.0                      NaN       NaN       NaN  ...       NaN       NaN       NaN
# 7.0                      NaN       NaN       NaN  ...       NaN       NaN       NaN
# 8.0                      NaN       NaN       NaN  ...  253900.0       NaN       NaN
# ...

# %%
print(df.median_house_value)
print(df['median_house_value'])
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({
   'X': ['A', 'B', 'O'],
   'Y': [15, 32, 12],
   'Z': [10, 29, 0],
   'T': [12, 28, 19]},
   index = [1, 2, 3]
)
df.head(3)
# Out:
#    X   Y   Z   T
# 1  A  15  10  12
# 2  B  32  29  28
# 3  O  12   0  19

# %%
mask = []
for it in df.iterrows():
  print(type(it), type(it[1]))
  
print(mask)

print(df[mask])
# Out:
# <class 'tuple'> <class 'pandas.core.series.Series'>
# <class 'tuple'> <class 'pandas.core.series.Series'>
# <class 'tuple'> <class 'pandas.core.series.Series'>
# []
# Empty DataFrame
# Columns: []
# Index: [1, 2, 3]

# %%
! wget https://covid19.who.int/WHO-COVID-19-global-table-data.csv
# Out:
# --2021-11-10 12:36:59--  https://covid19.who.int/WHO-COVID-19-global-table-data.csv
# Resolving covid19.who.int (covid19.who.int)... 65.8.49.64, 65.8.49.26, 65.8.49.57, ...
# Connecting to covid19.who.int (covid19.who.int)|65.8.49.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17386 (17K) [text/csv]
# Saving to: ‘WHO-COVID-19-global-table-data.csv’
#
# WHO-COVID-19-global 100%[===================>]  16.98K  --.-KB/s    in 0.001s
#
# 2021-11-10 12:36:59 (27.0 MB/s) - ‘WHO-COVID-19-global-table-data.csv’ saved [17386/17386]

# %%
df = pd.read_csv('covid_cases.csv', index_col=False)
df.head(5)
# Out:
#                        Name  ... Deaths - newly reported in last 24 hours
# 0                    Global  ...                                     6183
# 1  United States of America  ...                                      658
# 2                     India  ...                                      332
# 3                    Brazil  ...                                       59
# 4        The United Kingdom  ...                                       57
#
# [5 rows x 12 columns]

# %%
vn = df[df['Name'] == 'Viet Nam']
vn.head(1)
print(vn['WHO Region'])
print(vn['Cases - cumulative total'])
print(vn['Deaths - cumulative total'])
# Out:
# 38    Western Pacific
# Name: WHO Region, dtype: object
# 38    976672
# Name: Cases - cumulative total, dtype: int64
# 38    22598
# Name: Deaths - cumulative total, dtype: int64

# %%
western_pacific = df[df['WHO Region'] == 'Western Pacific']
western_pacific.head(5)
# Out:
#                  Name  ... Deaths - newly reported in last 24 hours
# 19        Philippines  ...                                       91
# 20           Malaysia  ...                                       58
# 27              Japan  ...                                        3
# 38           Viet Nam  ...                                       67
# 73  Republic of Korea  ...                                       18
#
# [5 rows x 12 columns]

# %%
print(western_pacific['Cases - cumulative total'].sum())
# Out:
# 9627397

# %%
print(western_pacific['Deaths - cumulative total'].sum())
# Out:
# 132817
